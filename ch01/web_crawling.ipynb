# %%
import urllib.request as req
import urllib.parse

# %%
res=req.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print(res.version)
res_headers=res.getheaders()

print('---[header 정보출력]---')
for header in res_headers:
    print(header)
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# 11
# ---[header 정보출력]---
# ('Date', 'Mon, 22 Jul 2024 03:30:16 GMT')
# ('content-type', 'text/html; charset=UTF-8')
# ('transfer-encoding', 'chunked')
# ('set-cookie', 'PM_CK_loc=6a99d2fc1b5471d9d14cea36ec9cb8ccbc593048dad883183ee247e5610d9706; Expires=Tue, 23 Jul 2024 03:30:16 GMT; Path=/; HttpOnly')
# ('cache-control', 'no-cache, no-store, must-revalidate')
# ('pragma', 'no-cache')
# ('x-frame-options', 'DENY')
# ('x-xss-protection', '1; mode=block')
# ('strict-transport-security', 'max-age=63072000; includeSubdomains')
# ('referrer-policy', 'unsafe-url')
# ('server', 'nfront')
# ('connection', 'close')

# %%
print('---[body 정보출력]---')
print(res.read().decode('utf-8'))
# Out:
# ---[body 정보출력]---
# ...

# %%
url='http://unico2013.dothome.co.kr/crawling/tagstyle.html'
res=req.urlopen(url)
print(res)
res_headers=res.getheaders()

for header in res_headers:
    print(header)

print(res.read().decode('utf-8'))
# Out:
# ...
# ('Date', 'Mon, 22 Jul 2024 03:39:21 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '484')
# ('Connection', 'close')
# ('Content-Type', 'text/html')
# <!DOCTYPE html>
# <html>
# <head>
#  <meta http-equiv="content-type" content="text/html; charset=utf-8">
# <title>HTML 학습</title>
# </head>
# <body>
# <h1>블럭스타일 태그</h1>
# <div style="background-color:yellow">테스트입니다1</div>
# <div>테스트입니다2</div>
# <div>테스트입니다3</div>
# <hr>
# <h1>인라인스타일 태그</h1>
# <span style="background-color:yellow">테스트입니다1</span>
# <span>테스트입니다2</span>
# <span>테스트입니다3</span>
# </body>
# </html>

# %%
url='https://cu.bgfretail.com/'
res=req.urlopen(url)
print(res)
res_headers=res.getheaders()

for header in res_headers:
    print(header)

print(res.read().decode('utf-8'))
# Out:
# ...
# ('Server', 'Oracle-HTTP-Server-11g')
# ('Date', 'Mon, 22 Jul 2024 03:40:01 GMT')
# ('Content-Type', 'text/html; charset=utf-8')
# ('Transfer-Encoding', 'chunked')
# ('Connection', 'close')
# ('Set-Cookie', 'JSESSIONID=90bYhnbszSQbsVpUUNC-gpMtmFTKbeWQSf_dHRTptlYeCV_foF52!-161315194; path=/; HttpOnly')
# ('Content-Language', 'en-US')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- head -->
#
#
#
#
#
#
#
#
#
#
#
#
# 	<link rel="canonical" href="http://cu.bgfretail.com" />.41" />편의점택배, 택배, 상품안내, 가맹 시스템, 창업 상담 제공." />
#
# 	 link rel="stylesheet" type="text/css" href="/css/font.css" media="all" />ll" /> <!-- 리뉴얼 css -->
# <!--  loading layer -->
# <style type="text/css">
# .AjaxLoading { display:none; position:fixed; left:0; top:0; width:100%; height:100%; z-index:1000;}
# .AjaxLoading .bg { position:absolute; left:0; top:0; z-index:1001; width:100%; height:100%; background:#000; opacity:0.6; filter:alpha(opacity=30);}
# ...

# %%
res=req.urlopen("http://www.naver.com/")
a=res.info().get_content_charset()
# print(type(a))
# b=a.get_content_charset()
# print(b)
print(res.read().decode(a))
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %%
url='http://unico2013.dothome.co.kr/crawling/tagstyle.html'
res=req.urlopen(url)

a=res.info()
print(type(a))
b=a.get_content_charset()
print(b)

# res_headers=res.getheaders()

# for header in res_headers:
#     print(header)
# Out:
# <class 'http.client.HTTPMessage'>
# None

# %%
data=urllib.parse.urlencode({'name':'유니코','age':20})
postdata=data.encode('ascii')
req1=urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php', data=postdata)
res=req.urlopen(req1)
print(res.read().decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 20이네요!!</h1>   </body>
# </html>

# %%
import urllib.parse
import urllib.request as req

# 파라미터를 딕셔너리 형태로 작성
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})

# URL에 파라미터 추가
url = 'http://unico2013.dothome.co.kr/crawling/get.php?%s' % params

# URL 요청
res = req.urlopen(url)

# URL과 결과 출력
print(url)
print(res.read().decode('utf-8'))
# Out:
# http://unico2013.dothome.co.kr/crawling/get.php?name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>GET TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
savename1='data/images/img01,jpg'
imgae=req.urlopen(url).read
f=open(savename1,mode='wb')
f.write(Image)
f.clsoe()
with open(savename1, mode-'wb') as f:
    f.write(image)
    print("저장되었습니다")

# %%
import requests
url='http://unico2013.dothome.co.kr/crawling/exam.html'
# res=requests.request('get',url)
res=requests.get(url)
res.encoding='utf-8'
print(type(res))
print(res.text)
# Out:
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>

# %%
html='''
<!DOCTYPE html>
<html>
    <head>
        <meta charset="UTF-8">
    <title>테스트</title>
    </head>
    <body>
        <h1>웹 크롤링을 테스트 합니다.</h1>
        <p align="center">P태그의 컨텍스트</p>
        <img src="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMDA3MjJfMjky%2FMDAxNTk1Mzk2MzAzMzk2.-ElCKMJg5sIRSuqn0E2aIQuVKf6PRGILEhW8Gi138wwg.F5Bosu4RtAbXE57pFWq3_8KarG2UufLUvXhCu1ttKuMg.JPEG.onsim_studio%2FIMG_1201.JPG&type=sc960_832" width="500" atl="바캉스">
        <ul>
            <li>테스트1<strong>강조</strong></li>
            <li>테스트2</li>
            <li>테스트3</li>
        </ul>
    </body>
</html>'''

# %%
from bs4 import BeautifulSoup as soup
bs1=soup(html, 'html.parser')
bs2=soup(html, 'lxml')
# bs3=soup(html, 'lxml-lxml')
# bs4=soup(html, 'html5lib')
print(type(bs1))
print(bs1)
print(bs2)
# Out:
# <class 'bs4.BeautifulSoup'>
#
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# <p align="center">P태그의 컨텍스트</p>
# <img atl="바캉스" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMDA3MjJfMjky%2FMDAxNTk1Mzk2MzAzMzk2.-ElCKMJg5sIRSuqn0E2aIQuVKf6PRGILEhW8Gi138wwg.F5Bosu4RtAbXE57pFWq3_8KarG2UufLUvXhCu1ttKuMg.JPEG.onsim_studio%2FIMG_1201.JPG&amp;type=sc960_832" width="500"/>
# <ul>
# <li>테스트1<strong>강조</strong></li>
# <li>테스트2</li>
# <li>테스트3</li>
# </ul>
# </body>
# </html>
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# <p align="center">P태그의 컨텍스트</p>
# ...

# %%
print(bs1.title)
print(bs1.p.string)
print(bs1.ul.li.string)
print(bs1.ul.li.text)
print(bs1.ul.text)
print(bs1.p['align'])
print(bs1.img['src'])
print(bs1.img.attrs)
print(bs1.ul.contents)
# Out:
# <title>테스트</title>
# P태그의 컨텍스트
# None
# 테스트1강조
#
# 테스트1강조
# 테스트2
# 테스트3
#
# center
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMDA3MjJfMjky%2FMDAxNTk1Mzk2MzAzMzk2.-ElCKMJg5sIRSuqn0E2aIQuVKf6PRGILEhW8Gi138wwg.F5Bosu4RtAbXE57pFWq3_8KarG2UufLUvXhCu1ttKuMg.JPEG.onsim_studio%2FIMG_1201.JPG&type=sc960_832
# {'src': 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMDA3MjJfMjky%2FMDAxNTk1Mzk2MzAzMzk2.-ElCKMJg5sIRSuqn0E2aIQuVKf6PRGILEhW8Gi138wwg.F5Bosu4RtAbXE57pFWq3_8KarG2UufLUvXhCu1ttKuMg.JPEG.onsim_studio%2FIMG_1201.JPG&type=sc960_832', 'width': '500', 'atl': '바캉스'}
# ['\n', <li>테스트1<strong>강조</strong></li>, '\n', <li>테스트2</li>, '\n', <li>테스트3</li>, '\n']

# %%
li_list=bs1.find_all('li')
print(li_list)
for li in li_list:
    print(li.get_text)
# Out:
# [<li>테스트1<strong>강조</strong></li>, <li>테스트2</li>, <li>테스트3</li>]
# <bound method PageElement.get_text of <li>테스트1<strong>강조</strong></li>>
# <bound method PageElement.get_text of <li>테스트2</li>>
# <bound method PageElement.get_text of <li>테스트3</li>>

# %%
import re
a=bs1.find_all(re.compile('^b'))

# %%
print(bs1)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# <p align="center">P태그의 컨텍스트</p>
# <img atl="바캉스" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMDA3MjJfMjky%2FMDAxNTk1Mzk2MzAzMzk2.-ElCKMJg5sIRSuqn0E2aIQuVKf6PRGILEhW8Gi138wwg.F5Bosu4RtAbXE57pFWq3_8KarG2UufLUvXhCu1ttKuMg.JPEG.onsim_studio%2FIMG_1201.JPG&amp;type=sc960_832" width="500"/>
# <ul>
# <li>테스트1<strong>강조</strong></li>
# <li>테스트2</li>
# <li>테스트3</li>
# </ul>
# </body>
# </html>

# %%
li_list=bs1.select('ul>li')
print(li_list)
p1=bs1.select_one('p')
print(p1)
# Out:
# [<li>테스트1<strong>강조</strong></li>, <li>테스트2</li>, <li>테스트3</li>]
# <p align="center">P태그의 컨텍스트</p>
