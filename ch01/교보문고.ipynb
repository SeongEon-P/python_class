# %%
import urllib.request as req
from bs4 import BeautifulSoup as soup
base='https://search.kyobobook.co.kr/search?keyword=python&gbCode=TOT&target=total'
book_list=[]

# %%
def image_save(bid):
  url='https://contents.kyobobook.co.kr/sih/fit-in/200x0/pdt/'+bid+'.jpg'
  save_path='data/images/'+bid+'.jpg'
  req.urlretrieve(url, save_path)
  print("이미지 저장", bid+".jpg")

# %%
html=req.urlopen(base)
bs=soup(html,'html.parser')
item_list=bs.select('#shopData_list > ul > li')
#print(item_list)
for item in item_list:
  title=item.select_one('div.prod_area.horizontal > div.prod_info_box > div.auto_overflow_wrap.prod_name_group > div.auto_overflow_contents > div > a')
  #print(title.text.strip().split('\n'))
  # title=item.select_one('#cmdtName_S000213913527')

  title=title.text.strip().split('\n')[-1].replace(',','').replace(":","_")
  #print(title)
  author=item.select_one('div.prod_area.horizontal > div.prod_info_box > div.prod_author_info > div.auto_overflow_wrap.prod_author_group > div.auto_overflow_contents > div>a')
  author=author.text.strip()
  price=item.select_one('div.prod_area.horizontal > div.prod_info_box > div.prod_price > span.price')
  if (price==None):
    price=0
  else:
    price=price.text.strip().split("\n")[0].replace(",",'').replace('무료도서','0')
  #print(title, author, price)
  pub=item.select_one('div.prod_area.horizontal > div.prod_info_box > div.prod_author_info > div.prod_publish > a')
  pub=pub.text

  pub_date=item.select_one('div.prod_area.horizontal > div.prod_info_box > div.prod_author_info > div.prod_publish > span.date')
  pub_date=pub_date.text
  book_list.append((title, author, price, pub, pub_date))
  #img=item.select_one('div.prod_area.horizontal > div.prod_thumb_box.size_lg > a > span > img')
  #print(img)
  #image_save(img['data-kbbfn-bid'])

# %%
book_list
# Out:
# [('파이썬컴퓨팅', '한종대', '14130', '한국인력리스', '2024년 07월 25일'),
#  ('파이썬과 AI 인공지능 카메라를 활용한 자율주행 자동차', '장문철', '22950', '앤써북', '2024년 08월 20일'),
#  ('네트워크 인프라 자동화 _SDN 개념부터 파이썬 리눅스 Ansible 활용까지',
#   '맷 오스왈트',
#   '58500',
#   '한빛미디어',
#   '2024년 08월 10일'),
#  ('파이썬과 자바스크립트로 배우는 OpenAI 프로그래밍', '쇼다 쓰야노', '28800', '제이펍', '2024년 08월 16일'),
#  ('파이썬으로 구현하는 로보어드바이저', '윤성진', '32400', '에이콘출판', '2024년 07월 31일'),
#  ('[무료특별판] 미국 주식으로 시작하는 슬기로운 퀀트투자', '김용환', '0', '한빛미디어', '2021년 10월 29일'),
#  ('파이썬으로 시작하는 데이터 분석', '강지영', '19800', '아이리포', '2021년 07월 15일'),
#  ('초보자를 위한 파이썬(Python) 200제', '장삼용', '18000', '정보문화사', '2017년 02월 27일'),
#  ('[epub3.0] (Better Python Code)파이썬 코딩의 기술 51',
#   '데이비드 메르츠 저자, 김진호 번역',
#   0,
#   '길벗',
#   '2024년 07월 18일'),
#  ('2024 빅데이터분석기사 실기 한권완성_ 파이썬(Python)',
#   '최예신',
#   '27000',
#   '예문에듀',
#   '2024년 05월 20일'),
#  ('누구나 할 수 있다 파이썬 Python 기초', '박빈', 0, '와이웨이브이퍼블리싱', '2024년 03월 22일'),
#  ('초보자를 위한 파이썬(Python) 200제', '장삼용', 0, '정보문화사', '2017년 03월 07일'),
#  ('Head First Python', '우정은', 0, '한빛미디어', '2017년 12월 11일'),
#  ('파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)',
#   '이경택',
#   0,
#   '정보문화사',
#   '2020년 11월 27일'),
#  ('파이썬(Python) 3학년 머신러닝의 구조', '모리 요시나오', '16200', '성안당', '2023년 09월 20일'),
#  ('생활코딩! 파이썬', '이고잉', '16200', '범', '2020년 03월 23일'),
#  ('파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)',
#   '이경택',
#   '22500',
#   '정보문화사',
#   '2020년 10월 08일'),
#  ('파이썬(Python)', '박병기', 0, '아티오', '2017년 01월 17일'),
#  ('Python(파이썬)과 Matplotlib NumPy Pandas', '양원영', 0, '유페이퍼', '2021년 03월 17일'),
#  ('파이썬(Python) 3학년 머신러닝의 구조', '모리 요시나오', 0, '성안당', '2023년 09월 12일')]

# %%
import pandas as pd
df=pd.DataFrame(book_list, 
                columns=['title','author','price','pub','pub_date'])
df.to_csv('data/book_list.csv', index=False)

# %%
#pymysql 라이브러리 사용 DB연결
import pymysql
def insert_book(book):
    conn=pymysql.connect(
        host='localhost',
        user='pse',
        password='1234',
        db='pydb',
        charset='utf8')
    cursor=conn.cursor()
    sql="""insert into book_tbl(title, author, price, pub, pub_date)
    values(%s, %s, %s, %s, %s)"""
    cursor.executemany(sql, book)
    conn.commit()
    conn.close()

insert_book(book_list)

# %%
def select_all():
 conn = pymysql.connect( 
    host='localhost', 
    user='pse', 
    password='1234',
    db='pydb', 
    charset='utf8')
 cursor=conn.cursor()
 sql="select * from book_tbl"
 cursor.execute(sql)

 for book in cursor:
    print(book)
 conn.close()

select_all()
# Out:
# (1, '파이썬컴퓨팅', '한종대', '14130', '한국인력리스', '2024년 07월 25일')
# (2, '파이썬과 AI 인공지능 카메라를 활용한 자율주행 자동차', '장문철', '22950', '앤써북', '2024년 08월 20일')
# (3, '네트워크 인프라 자동화 _SDN 개념부터 파이썬 리눅스 Ansible 활용까지', '맷 오스왈트', '58500', '한빛미디어', '2024년 08월 10일')
# (4, '파이썬과 자바스크립트로 배우는 OpenAI 프로그래밍', '쇼다 쓰야노', '28800', '제이펍', '2024년 08월 16일')
# (5, '파이썬으로 구현하는 로보어드바이저', '윤성진', '32400', '에이콘출판', '2024년 07월 31일')
# (6, '[무료특별판] 미국 주식으로 시작하는 슬기로운 퀀트투자', '김용환', '0', '한빛미디어', '2021년 10월 29일')
# (7, '파이썬으로 시작하는 데이터 분석', '강지영', '19800', '아이리포', '2021년 07월 15일')
# (8, '초보자를 위한 파이썬(Python) 200제', '장삼용', '18000', '정보문화사', '2017년 02월 27일')
# (9, '[epub3.0] (Better Python Code)파이썬 코딩의 기술 51', '데이비드 메르츠 저자, 김진호 번역', '0', '길벗', '2024년 07월 18일')
# (10, '2024 빅데이터분석기사 실기 한권완성_ 파이썬(Python)', '최예신', '27000', '예문에듀', '2024년 05월 20일')
# (11, '누구나 할 수 있다 파이썬 Python 기초', '박빈', '0', '와이웨이브이퍼블리싱', '2024년 03월 22일')
# (12, '초보자를 위한 파이썬(Python) 200제', '장삼용', '0', '정보문화사', '2017년 03월 07일')
# (13, 'Head First Python', '우정은', '0', '한빛미디어', '2017년 12월 11일')
# (14, '파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)', '이경택', '0', '정보문화사', '2020년 11월 27일')
# (15, '파이썬(Python) 3학년 머신러닝의 구조', '모리 요시나오', '16200', '성안당', '2023년 09월 20일')
# (16, '생활코딩! 파이썬', '이고잉', '16200', '범', '2020년 03월 23일')
# (17, '파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)', '이경택', '22500', '정보문화사', '2020년 10월 08일')
# (18, '파이썬(Python)', '박병기', '0', '아티오', '2017년 01월 17일')
# (19, 'Python(파이썬)과 Matplotlib NumPy Pandas', '양원영', '0', '유페이퍼', '2021년 03월 17일')
# (20, '파이썬(Python) 3학년 머신러닝의 구조', '모리 요시나오', '0', '성안당', '2023년 09월 12일')
# (21, '파이썬컴퓨팅', '한종대', '14130', '한국인력리스', '2024년 07월 25일')
# (22, '파이썬과 AI 인공지능 카메라를 활용한 자율주행 자동차', '장문철', '22950', '앤써북', '2024년 08월 20일')
# (23, '네트워크 인프라 자동화 _SDN 개념부터 파이썬 리눅스 Ansible 활용까지', '맷 오스왈트', '58500', '한빛미디어', '2024년 08월 10일')
# (24, '파이썬과 자바스크립트로 배우는 OpenAI 프로그래밍', '쇼다 쓰야노', '28800', '제이펍', '2024년 08월 16일')
# (25, '파이썬으로 구현하는 로보어드바이저', '윤성진', '32400', '에이콘출판', '2024년 07월 31일')
# (26, '[무료특별판] 미국 주식으로 시작하는 슬기로운 퀀트투자', '김용환', '0', '한빛미디어', '2021년 10월 29일')
# (27, '파이썬으로 시작하는 데이터 분석', '강지영', '19800', '아이리포', '2021년 07월 15일')
# (28, '초보자를 위한 파이썬(Python) 200제', '장삼용', '18000', '정보문화사', '2017년 02월 27일')
# (29, '[epub3.0] (Better Python Code)파이썬 코딩의 기술 51', '데이비드 메르츠 저자, 김진호 번역', '0', '길벗', '2024년 07월 18일')
# (30, '2024 빅데이터분석기사 실기 한권완성_ 파이썬(Python)', '최예신', '27000', '예문에듀', '2024년 05월 20일')
# (31, '누구나 할 수 있다 파이썬 Python 기초', '박빈', '0', '와이웨이브이퍼블리싱', '2024년 03월 22일')
# (32, '초보자를 위한 파이썬(Python) 200제', '장삼용', '0', '정보문화사', '2017년 03월 07일')
# (33, 'Head First Python', '우정은', '0', '한빛미디어', '2017년 12월 11일')
# (34, '파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)', '이경택', '0', '정보문화사', '2020년 11월 27일')
# (35, '파이썬(Python) 3학년 머신러닝의 구조', '모리 요시나오', '16200', '성안당', '2023년 09월 20일')
# (36, '생활코딩! 파이썬', '이고잉', '16200', '범', '2020년 03월 23일')
# (37, '파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)', '이경택', '22500', '정보문화사', '2020년 10월 08일')
# (38, '파이썬(Python)', '박병기', '0', '아티오', '2017년 01월 17일')
# (39, 'Python(파이썬)과 Matplotlib NumPy Pandas', '양원영', '0', '유페이퍼', '2021년 03월 17일')
# (40, '파이썬(Python) 3학년 머신러닝의 구조', '모리 요시나오', '0', '성안당', '2023년 09월 12일')

# %%
import urllib.request as req
from bs4 import BeautifulSoup as soup
base='https://search.kyobobook.co.kr/search?keyword=%EA%B0%9C%EB%B0%9C%EC%9E%90&gbCode=TOT&target=total'
book_list2=[]

# %%
def image_save(bid):
  url='https://contents.kyobobook.co.kr/sih/fit-in/200x0/pdt/'+bid+'.jpg'
  save_path='data/images/'+bid+'.jpg'
  req.urlretrieve(url, save_path)
  print("이미지 저장", bid+".jpg")

# %%
html=req.urlopen(base)
bs=soup(html,'html.parser')
item_list=bs.select('#shopData_list > ul > li')
#print(item_list)
for item in item_list:
  title=item.select_one('div.prod_area.horizontal > div.prod_info_box > div.auto_overflow_wrap.prod_name_group > div.auto_overflow_contents > div > a')
  #print(title.text.strip().split('\n'))
  # title=item.select_one('#cmdtName_S000213907278')
  title=title.text.strip().split('\n')[-1].replace(',','').replace(":","_")
  #print(title)
  author=item.select_one('div.prod_area.horizontal > div.prod_info_box > div.prod_author_info > div.auto_overflow_wrap.prod_author_group > div.auto_overflow_contents > div>a')
  author=author.text.strip()
  price=item.select_one('div.prod_area.horizontal > div.prod_info_box > div.prod_price > span.price')
  if (price==None):
    price=0
  else:
    price=price.text.strip().split("\n")[0].replace(",",'').replace('무료도서','0')
  #print(title, author, price)
  pub=item.select_one('div.prod_area.horizontal > div.prod_info_box > div.prod_author_info > div.prod_publish > a')
  pub=pub.text

  pub_date=item.select_one('div.prod_area.horizontal > div.prod_info_box > div.prod_author_info > div.prod_publish > span.date')
  pub_date=pub_date.text
  book_list2.append((title, author, price, pub, pub_date))
  #img=item.select_one('div.prod_area.horizontal > div.prod_thumb_box.size_lg > a > span > img')
  #print(img)
  #image_save(img['data-kbbfn-bid'])

# %%
#pymysql 라이브러리 사용 DB연결
import pymysql
def insert_book(book):
    conn=pymysql.connect(
        host='localhost',
        user='pse',
        password='1234',
        db='pydb',
        charset='utf8')
    cursor=conn.cursor()
    sql="""insert into book_tbl(title, author, price, pub, pub_date)
    values(%s, %s, %s, %s, %s)"""
    cursor.executemany(sql, book)
    conn.commit()
    conn.close()

insert_book(book_list2)

# %%
def select_all():
 conn = pymysql.connect( 
    host='localhost', 
    user='pse', 
    password='1234',
    db='pydb', 
    charset='utf8')
 cursor=conn.cursor()
 sql="select * from book_tbl"
 cursor.execute(sql)

 for book in cursor:
    print(book)
 conn.close()

select_all()
# Out:
# (1, '파이썬컴퓨팅', '한종대', '14130', '한국인력리스', '2024년 07월 25일')
# (2, '파이썬과 AI 인공지능 카메라를 활용한 자율주행 자동차', '장문철', '22950', '앤써북', '2024년 08월 20일')
# (3, '네트워크 인프라 자동화 _SDN 개념부터 파이썬 리눅스 Ansible 활용까지', '맷 오스왈트', '58500', '한빛미디어', '2024년 08월 10일')
# (4, '파이썬과 자바스크립트로 배우는 OpenAI 프로그래밍', '쇼다 쓰야노', '28800', '제이펍', '2024년 08월 16일')
# (5, '파이썬으로 구현하는 로보어드바이저', '윤성진', '32400', '에이콘출판', '2024년 07월 31일')
# (6, '[무료특별판] 미국 주식으로 시작하는 슬기로운 퀀트투자', '김용환', '0', '한빛미디어', '2021년 10월 29일')
# (7, '파이썬으로 시작하는 데이터 분석', '강지영', '19800', '아이리포', '2021년 07월 15일')
# (8, '초보자를 위한 파이썬(Python) 200제', '장삼용', '18000', '정보문화사', '2017년 02월 27일')
# (9, '[epub3.0] (Better Python Code)파이썬 코딩의 기술 51', '데이비드 메르츠 저자, 김진호 번역', '0', '길벗', '2024년 07월 18일')
# (10, '2024 빅데이터분석기사 실기 한권완성_ 파이썬(Python)', '최예신', '27000', '예문에듀', '2024년 05월 20일')
# (11, '누구나 할 수 있다 파이썬 Python 기초', '박빈', '0', '와이웨이브이퍼블리싱', '2024년 03월 22일')
# (12, '초보자를 위한 파이썬(Python) 200제', '장삼용', '0', '정보문화사', '2017년 03월 07일')
# (13, 'Head First Python', '우정은', '0', '한빛미디어', '2017년 12월 11일')
# (14, '파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)', '이경택', '0', '정보문화사', '2020년 11월 27일')
# (15, '파이썬(Python) 3학년 머신러닝의 구조', '모리 요시나오', '16200', '성안당', '2023년 09월 20일')
# (16, '생활코딩! 파이썬', '이고잉', '16200', '범', '2020년 03월 23일')
# (17, '파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)', '이경택', '22500', '정보문화사', '2020년 10월 08일')
# (18, '파이썬(Python)', '박병기', '0', '아티오', '2017년 01월 17일')
# (19, 'Python(파이썬)과 Matplotlib NumPy Pandas', '양원영', '0', '유페이퍼', '2021년 03월 17일')
# (20, '파이썬(Python) 3학년 머신러닝의 구조', '모리 요시나오', '0', '성안당', '2023년 09월 12일')
# (21, '파이썬컴퓨팅', '한종대', '14130', '한국인력리스', '2024년 07월 25일')
# (22, '파이썬과 AI 인공지능 카메라를 활용한 자율주행 자동차', '장문철', '22950', '앤써북', '2024년 08월 20일')
# (23, '네트워크 인프라 자동화 _SDN 개념부터 파이썬 리눅스 Ansible 활용까지', '맷 오스왈트', '58500', '한빛미디어', '2024년 08월 10일')
# (24, '파이썬과 자바스크립트로 배우는 OpenAI 프로그래밍', '쇼다 쓰야노', '28800', '제이펍', '2024년 08월 16일')
# (25, '파이썬으로 구현하는 로보어드바이저', '윤성진', '32400', '에이콘출판', '2024년 07월 31일')
# (26, '[무료특별판] 미국 주식으로 시작하는 슬기로운 퀀트투자', '김용환', '0', '한빛미디어', '2021년 10월 29일')
# (27, '파이썬으로 시작하는 데이터 분석', '강지영', '19800', '아이리포', '2021년 07월 15일')
# (28, '초보자를 위한 파이썬(Python) 200제', '장삼용', '18000', '정보문화사', '2017년 02월 27일')
# (29, '[epub3.0] (Better Python Code)파이썬 코딩의 기술 51', '데이비드 메르츠 저자, 김진호 번역', '0', '길벗', '2024년 07월 18일')
# (30, '2024 빅데이터분석기사 실기 한권완성_ 파이썬(Python)', '최예신', '27000', '예문에듀', '2024년 05월 20일')
# (31, '누구나 할 수 있다 파이썬 Python 기초', '박빈', '0', '와이웨이브이퍼블리싱', '2024년 03월 22일')
# (32, '초보자를 위한 파이썬(Python) 200제', '장삼용', '0', '정보문화사', '2017년 03월 07일')
# (33, 'Head First Python', '우정은', '0', '한빛미디어', '2017년 12월 11일')
# (34, '파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)', '이경택', '0', '정보문화사', '2020년 11월 27일')
# (35, '파이썬(Python) 3학년 머신러닝의 구조', '모리 요시나오', '16200', '성안당', '2023년 09월 20일')
# (36, '생활코딩! 파이썬', '이고잉', '16200', '범', '2020년 03월 23일')
# (37, '파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)', '이경택', '22500', '정보문화사', '2020년 10월 08일')
# (38, '파이썬(Python)', '박병기', '0', '아티오', '2017년 01월 17일')
# (39, 'Python(파이썬)과 Matplotlib NumPy Pandas', '양원영', '0', '유페이퍼', '2021년 03월 17일')
# (40, '파이썬(Python) 3학년 머신러닝의 구조', '모리 요시나오', '0', '성안당', '2023년 09월 12일')
# (41, '기본기가 탄탄한 자바 개발자', '벤저민 J. 에번스', '40500', '제이펍', '2024년 08월 14일')
# (42, '[무료전자책] 이경오의 SQL+SQLD 비밀노트 - 기본 및 활용 편', '이경오', '0', '한빛미디어', '2021년 10월 29일')
# (43, '얄코의 TOO MUCH 친절한 깃&깃허브(무료특별판)', '고현민', '0', '리코멘드', '2023년 08월 10일')
# (44, '[무료전자책] 이경오의 SQL+SQLD 비밀노트 - 시험 직전 비밀노트 편', '이경오', '0', '한빛미디어', '2021년 10월 29일')
# (45, '2024 SD에듀 유선배 SQL개발자(SQLD) 과외노트', '정미나', '21600', '시대고시기획', '2024년 02월 05일')
# (46, '개발자를 위한 필수 수학', '토머스 닐드', '27000', '한빛미디어', '2024년 06월 03일')
# (47, '친절한 SQL 튜닝', '조시형', '34200', '디비안(주)(DBian)', '2018년 06월 01일')
# (48, '면접을 위한 CS 전공지식 노트', '주홍철', '21600', '길벗', '2022년 04월 28일')
# (49, '퇴사한 게임 개발자가 너무 유능함', '강선우', '대여/소장 가능', 'KW북스', '2024년 01월 11일')
# (50, '2024 이기적 SQL 개발자 이론서+기출문제', '임호진', '21600', '영진닷컴', '2024년 01월 26일')
# (51, '자바/스프링 개발자를 위한 실용주의 프로그래밍', '김우근', '28800', '위키북스', '2024년 06월 11일')
# (52, '면접을 위한 CS 전공지식 노트', '주홍철', '0', '길벗', '2022년 05월 06일')
# (53, '개발자 원칙', '박성철', '19800', '골든래빗(주)', '2022년 12월 20일')
# (54, '개발자를 위한 생각의 정리 문서 작성법', '카이마이 미즈히로', '18000', '프리렉', '2024년 05월 17일')
# (55, '개발자를 위한 필수 수학', '토머스 닐드', '0', '한빛미디어', '2024년 06월 03일')
# (56, '개발자 기술 면접 노트', '이남희', '19800', '한빛미디어', '2024년 03월 25일')
# (57, '인공지능 구조 원리 교과서', '송경빈', '17820', '보누스', '2024년 03월 25일')
# (58, 'Real MySQL 8.0 (1권)', '백은빈', '27000', '위키북스', '2021년 09월 08일')
# (59, 'Do it! IT 서비스 이해를 위한 네트워크 기초', '심준보', '19800', '이지스퍼블리싱', '2024년 07월 08일')
# (60, '스프링 부트 3 백엔드 개발자 되기_ 자바 편', '신선영', '28800', '골든래빗(주)', '2024년 04월 05일')
