# %%
# ! pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.23.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\tjddj\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.2)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.26.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\tjddj\anaconda3\lib\site-packages (from selenium) (2024.6.2)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\tjddj\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\tjddj\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: sortedcontainers in c:\users\tjddj\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\tjddj\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\tjddj\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\tjddj\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\tjddj\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\tjddj\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\tjddj\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.23.1-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB 8.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/9.4 MB 12.7 MB/s eta 0:00:01
#    -------- ------------------------------- 2.0/9.4 MB 16.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.8/9.4 MB 16.1 MB/s eta 0:00:01
#    --------------- ------------------------ 3.7/9.4 MB 16.7 MB/s eta 0:00:01
#    ------------------ --------------------- 4.4/9.4 MB 16.7 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.4 MB 16.5 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.4 MB 16.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.4 MB 16.6 MB/s eta 0:00:01
#    -------------------------------- ------- 7.7/9.4 MB 17.6 MB/s eta 0:00:01
#    ------------------------------------ --- 8.6/9.4 MB 17.6 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.4 MB 17.4 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.4 MB 17.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.1/9.4 MB 14.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 14.0 MB/s eta 0:00:00
# Downloading trio-0.26.0-py3-none-any.whl (475 kB)
#    ---------------------------------------- 0.0/475.7 kB ? eta -:--:--
#    --------------------------------------- 475.7/475.7 kB 29.1 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB ? eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: wsproto, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-23.2.0 outcome-1.3.0.post0 selenium-4.23.1 trio-0.26.0 trio-websocket-0.11.1 wsproto-1.2.0

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome()
driver.get("http://www.google.com/ncr")
# target=driver.find_element(By.CSS_SELECTOR,"[name='q']")
# target=driver.find_element(By.ID,"APjFqb")
# target=driver.find_element(By.CLASS_NAME,"gLFyf")
# target=driver.find_element(By.TAG_NAME,"textarea")
target=driver.find_element(By.CSS_SELECTOR,"#APjFqb")
target.send_keys('파이썬')
target.send_keys(Keys.ENTER)
# driver.quit()

# %%
#스타벅스 매장위치를 정적인 방법으로 들고와보는 코드_결과는 안됨
import urllib.request as req
from bs4 import BeautifulSoup as soup

server=req.urlopen('https://www.starbucks.co.kr/store/store_map.do')
res=server.read().decode('utf-8')
bs=soup(res, 'html.parser')
li_list=bs.select_one('#mCSB_1_container > ul > li')
print(li_list)
# Out:
# None

# %%
#스타벅스 매장위치를 동적인 방법으로 들고와보는 코드
from selenium import webdriver
from selenium.webdriver.common.by import By

driver=webdriver.Chrome()
driver.implicitly_wait(3)
driver.get('https://www.starbucks.co.kr/store/store_map.do')
# targets=driver.find_elements(By.CLASS_NAME, 'quickResultLstCon')
targets=driver.find_elements(By.CSS_SELECTOR, '#mCSB_1_container > ul > li')
for item in targets:
    print(item.text)
# Out:
# 서면역
# 부산광역시 부산진구 서전로 1 (부전동)
# 1522-3232
# 리저브 매장 2번
# 부산서면중앙로
# 부산광역시 부산진구 중앙대로 701 (부전동)
# 1522-3232
# 리저브 매장 2번
# 서면중앙
# 부산광역시 부산진구 서면로68번길 1 (부전동)
# 1522-3232
# 리저브 매장 2번

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver=webdriver.Chrome()
driver.implicitly_wait(3)
driver.get('https://www.starbucks.co.kr/store/store_map.do')

# %%
s_link=driver.find_element(By.CSS_SELECTOR,'#container > div > form > fieldset > div > section > article.find_store_cont > article > header.loca_search > h3 > a')
s_link.click()

s_link2=driver.find_element(By.CSS_SELECTOR, 'div.loca_step1_cont > ul > li:nth-child(1) > a')
s_link2.click()

s_link3=driver.find_element(By.CSS_SELECTOR, '#mCSB_2_container > ul > li:nth-child(2) > a')
s_link3.click()

shop_list=driver.find_elements(By.CSS_SELECTOR, '#mCSB_3_container > ul > li')
for shop in shop_list:
    print(shop.text)
# Out:
# 강남세곡DT
# 서울특별시 강남구 헌릉로 727 (세곡동)
# 1522-3232
# 리저브 매장 2번
# 역삼이마트
# 서울특별시 강남구 역삼로 310 (역삼동)
# 1522-3232
# 리저브 매장 2번
# 압구정현대아파트
# 서울특별시 강남구 논현로175길 38 (신사동)
# 1522-3232
# 리저브 매장 2번

# %%
temp_list=[]
time.sleep(2)
count=0
total=len(shop_list);print(total)

for shop in shop_list:
    count+=1
    shoplat=shop.get_attribute('data-lat')
    shoplong=shop.get_attribute('data-long')
    # print(shoplat, shoplong)
    shopname=shop.find_element(By.TAG_NAME,'strong')
    shopinfo=shop.find_element(By.TAG_NAME, 'p')
    shopinfo2=shopinfo.text.split("\n")
    if(len(shopinfo2)==2):
        shopaddr=shopinfo2[0]
        shopphone=shopinfo2[1]

    temp=(shopname.text, shoplat, shoplong, shopaddr, shopphone)
    temp_list.append(temp)

    #스크롤해서 데이터를 여는법
    if count != total and count %3==0:
        driver.execute_script("var su=arguments[0]; \
                              var dom=document.querySelectorAll('#mCSB_3_container > ul > li')[su]; \
                              dom.scrollIntoView();",count)
print(temp_list)
    # print(shopname.text,shoplat, shoplong, shopaddr, shopphone)
# Out:
# 91
# [('강남세곡DT', '37.466993809277', '127.118330806807', '서울특별시 강남구 헌릉로 727 (세곡동)', '1522-3232'), ('역삼이마트', '37.499367', '127.048425', '서울특별시 강남구 역삼로 310 (역삼동)', '1522-3232'), ('압구정현대아파트', '37.52521971236768', '127.0256601858147', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.5194407323478', '127.049552661542', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.510843366121534', '127.06363342044263', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.5078978596254', '127.023338614644', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.50383', '127.04487', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.509206962541256', '127.06560851480327', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.4970572543978', '127.028180714381', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.50777565616907', '127.0365882862214', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.500313', '127.066961', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.467274319644', '127.099929726', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.51966', '127.0341', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.50369465391196', '127.04172081609172', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.513019', '127.059838', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.4873267937748', '127.103140081887', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.4828551359882', '127.0607152444621', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.4984818', '127.052066', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.51736229999999', '127.02329570000006', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.51159269029387', '127.03219311069766', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.50498118534617', '127.0468080752464', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.50576457783876', '127.05804488086114', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.502721', '127.044308', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.526549', '127.040437', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.4964557', '127.02968850000002', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.509013311862645', '127.0403523996554', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.528115', '127.036441', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.492209', '127.039389', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.515351', '127.060109', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.50393894', '127.0485135', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.523912710310014', '127.02807214378778', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.5018592', '127.03727759999992', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.51350444312708', '127.05273753314826', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.51075489999999', '127.04455970000003', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.49803646', '127.0684943', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.49971982', '127.0349084', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.47781106', '127.0451411', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.493554', '127.061874', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.5165849', '127.04124330000002', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.50236693', '127.0407', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.49592355', '127.0388645', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.52680046', '127.0347174', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.52674095', '127.0281105', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.50377562', '127.051196', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.50689645929321', '127.05571872453659', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.490298', '127.054895', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.49966175', '127.0622171', '서울특별시 강남구 논현로175길 38 (신사동)', '1522-3232'), ('', '37.51464884', '127.0307302', '서울특별시 강남구 논현로175길  ...

# %%
#부산 진구의 매장 정보
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver=webdriver.Chrome()
driver.implicitly_wait(3)
driver.get('https://www.starbucks.co.kr/store/store_map.do')

s_link=driver.find_element(By.CSS_SELECTOR,'#container > div > form > fieldset > div > section > article.find_store_cont > article > header.loca_search > h3 > a')
s_link.click()

s_link2=driver.find_element(By.CSS_SELECTOR, 'div.loca_step1_cont > ul > li:nth-child(6) > a')
s_link2.click()

s_link3=driver.find_element(By.CSS_SELECTOR, '#mCSB_2_container > ul > li:nth-child(8) > a')
s_link3.click()

shop_list=driver.find_elements(By.CSS_SELECTOR, '#mCSB_3_container > ul > li')
for shop in shop_list:
    print(shop.text)
# Out:
# 서면문화로
# 부산광역시 부산진구 서면문화로 10 (부전동)
# 1522-3232
# 리저브 매장 2번
# 서면엠디엠타워
# 부산광역시 부산진구 중앙대로 639 (범천동)
# 1522-3232
# 리저브 매장 2번
# 초읍대공원
# 부산광역시 부산진구 성지곡로 6 (초읍동)
# 1522-3232
# 리저브 매장 2번

# %%
temp_list=[]
time.sleep(2)
count=0
total=len(shop_list);print(total)

for shop in shop_list:
    count+=1
    shoplat=shop.get_attribute('data-lat')
    shoplong=shop.get_attribute('data-long')
    # print(shoplat, shoplong)
    shopname=shop.find_element(By.TAG_NAME,'strong')
    shopinfo=shop.find_element(By.TAG_NAME, 'p')
    shopinfo2=shopinfo.text.split("\n")
    if(len(shopinfo2)==2):
        shopaddr=shopinfo2[0]
        shopphone=shopinfo2[1]

    temp=(shopname.text, shoplat, shoplong, shopaddr, shopphone)
    temp_list.append(temp)

    #스크롤해서 데이터를 여는법
   
    if count != total and count %3==0:
     driver.execute_script("var su=arguments[0]; \
      var dom=document.querySelectorAll('#mCSB_3_container > ul > li')[su];\
                              dom.scrollIntoView();",count)

for shop in temp_list:
   print(shop)
# Out:
# 18
# ('서면문화로', '35.15885783683483', '129.057495917852', '부산광역시 부산진구 서면문화로 10 (부전동)', '1522-3232')
# ('서면엠디엠타워', '35.14952733402157', '129.05889300302496', '부산광역시 부산진구 중앙대로 639 (범천동)', '1522-3232')
# ('초읍대공원', '35.1828193069829', '129.04748360769', '부산광역시 부산진구 성지곡로 6 (초읍동)', '1522-3232')
# ('서면트레이더스', '35.163831285849966', '129.0530396365257', '부산광역시 부산진구 시민공원로 31 (부암동)', '1522-3232')
# ('서면중앙', '35.15685353046891', '129.05798035954555', '부산광역시 부산진구 서면로68번길 1 (부전동)', '1522-3232')
# ('서면메디컬거리', '35.157961', '129.05740949999995', '부산광역시 부산진구 가야대로 783-1, 1층 (부전동)', '1522-3232')
# ('서면센트럴스퀘어', '35.1516177133099', '129.06089873180213', '부산광역시 부산진구 중앙대로666번길 50 (부전동)', '1522-3232')
# ('부전역', '35.16181113722542', '129.06201461279443', '부산광역시 부산진구 중앙대로 777, 서면호텔 복합시설1,2층 (부전동)', '1522-3232')
# ('서면역', '35.15789381388878', '129.0600009198993', '부산광역시 부산진구 서전로 1 (부전동)', '1522-3232')
# ('부산서면', '35.154098', '129.061562', '부산광역시 부산진구 중앙대로692번길 46-10 (부전동)', '1522-3232')
# ('서면서전로', '35.157919185437365', '129.0619520174245', '부산광역시 부산진구 서전로 19 (부전동)', '1522-3232')
# ('부산서면중앙로', '35.1554897646539', '129.0589527478538', '부산광역시 부산진구 중앙대로 701 (부전동)', '1522-3232')
# ('서면전포역', '35.154364828346324', '129.06362887930075', '부산광역시 부산진구 전포대로199번길 27 (전포동)', '1522-3232')
# ('부산개금역', '35.1529820637631', '129.02259825927663', '부산광역시 부산진구 가야대로 462 (개금동)', '1522-3232')
# ('동의대역', '35.15495095970587', '129.03618733441533', '부산광역시 부산진구 가야대로 589 (가야제1동)', '1522-3232')
# ('양정역', '35.170171720959104', '129.0692742371578', '부산광역시 부산진구 중앙대로 894 (양정동)', '1522-3232')
# ('서면로R', '35.15524851626055', '129.0576381743508', '부산광역시 부산진구 서면로 49-1 (부전동)', '1522-3232')
# ('서면중앙대로R', '35.15286800166649', '129.05944626017197', '부산광역시 부산진구 중앙대로 672 (부전동) 1층 2층', '1522-3232')

# %%
#부산진구의 스타벅스 매장정보 크롤링 후 데이터프레임 작성, csv파일로 저장
import pandas as pd
df=pd.DataFrame(temp_list, 
                columns=['shopname','shoplat','shoplong','shopaddr','shopphone'])
df.to_csv('data/starbucks_busanJinGu_list.csv', index=False)

# %%
#pymysql 라이브러리 사용 DB연결
import pymysql
def insert_shop(shop):
    conn=pymysql.connect(
        host='localhost',
        user='pse',
        password='1234',
        db='pydb',
        charset='utf8')
    cursor=conn.cursor()
    sql="""insert into starbucks_busanJinGu_tbl(shopname, shoplat, shoplong, shopaddr, shopphone)
    values(%s, %s, %s, %s, %s)"""
    cursor.executemany(sql, shop)
    conn.commit()
    conn.close()

insert_shop(temp_list)

# %%
def select_all():
 conn = pymysql.connect( 
    host='localhost', 
    user='pse', 
    password='1234',
    db='pydb', 
    charset='utf8')
 cursor=conn.cursor()
 sql="select * from starbucks_busanJinGu_tbl"
 cursor.execute(sql)

 for shop in cursor:
    print(shop)
 conn.close()

select_all()
# Out:
# (1, '서면문화로', '35.15885783683483', '129.057495917852', '부산광역시 부산진구 서면문화로 10 (부전동)', '1522-3232')
# (2, '서면엠디엠타워', '35.14952733402157', '129.05889300302496', '부산광역시 부산진구 중앙대로 639 (범천동)', '1522-3232')
# (3, '초읍대공원', '35.1828193069829', '129.04748360769', '부산광역시 부산진구 성지곡로 6 (초읍동)', '1522-3232')
# (4, '서면트레이더스', '35.163831285849966', '129.0530396365257', '부산광역시 부산진구 시민공원로 31 (부암동)', '1522-3232')
# (5, '서면중앙', '35.15685353046891', '129.05798035954555', '부산광역시 부산진구 서면로68번길 1 (부전동)', '1522-3232')
# (6, '서면메디컬거리', '35.157961', '129.05740949999995', '부산광역시 부산진구 가야대로 783-1, 1층 (부전동)', '1522-3232')
# (7, '서면센트럴스퀘어', '35.1516177133099', '129.06089873180213', '부산광역시 부산진구 중앙대로666번길 50 (부전동)', '1522-3232')
# (8, '부전역', '35.16181113722542', '129.06201461279443', '부산광역시 부산진구 중앙대로 777, 서면호텔 복합시설1,2층 (부전동)', '1522-3232')
# (9, '서면역', '35.15789381388878', '129.0600009198993', '부산광역시 부산진구 서전로 1 (부전동)', '1522-3232')
# (10, '부산서면', '35.154098', '129.061562', '부산광역시 부산진구 중앙대로692번길 46-10 (부전동)', '1522-3232')
# (11, '서면서전로', '35.157919185437365', '129.0619520174245', '부산광역시 부산진구 서전로 19 (부전동)', '1522-3232')
# (12, '부산서면중앙로', '35.1554897646539', '129.0589527478538', '부산광역시 부산진구 중앙대로 701 (부전동)', '1522-3232')
# (13, '서면전포역', '35.154364828346324', '129.06362887930075', '부산광역시 부산진구 전포대로199번길 27 (전포동)', '1522-3232')
# (14, '부산개금역', '35.1529820637631', '129.02259825927663', '부산광역시 부산진구 가야대로 462 (개금동)', '1522-3232')
# (15, '동의대역', '35.15495095970587', '129.03618733441533', '부산광역시 부산진구 가야대로 589 (가야제1동)', '1522-3232')
# (16, '양정역', '35.170171720959104', '129.0692742371578', '부산광역시 부산진구 중앙대로 894 (양정동)', '1522-3232')
# (17, '서면로R', '35.15524851626055', '129.0576381743508', '부산광역시 부산진구 서면로 49-1 (부전동)', '1522-3232')
# (18, '서면중앙대로R', '35.15286800166649', '129.05944626017197', '부산광역시 부산진구 중앙대로 672 (부전동) 1층 2층', '1522-3232')
